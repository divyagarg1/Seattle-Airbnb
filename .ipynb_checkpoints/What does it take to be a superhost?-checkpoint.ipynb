# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

df_listings = pd.read_csv('./listings.csv')
np.shape(df_listings)
# Out:
# (3818, 92)

# %%
#Checking how many total hosts are there?

np.shape(np.unique(df_listings['host_id']))
# Out:
# (2751,)

# %%
#How many superhosts are there?
def is_superhost(superhost):
    '''
    INPUT
        superhost - a string of one of the values from the host is a superhost column
    
    OUTPUT
        return 1 if the host is a superhost has value 't'
        return 0 otherwise
    
    '''
    if superhost in ['t']:
        return 1; 
    else:
        return 0
    

df_listings["host_is_superhost"].apply(is_superhost)[:5] #Test your function to assure it provides 1 and 0 values for the df
# Out:
# 0    0
# 1    1
# 2    0
# 3    0
# 4    0
# Name: host_is_superhost, dtype: int64

# %%
# Check how many superhosts
df_listings['Superhost?'] = df_listings["host_is_superhost"].apply(is_superhost)
superhost_perc = df_listings['Superhost?'].mean()
superhost_perc
# Out:
# 0.2037716081718177

# %% [markdown]
# 20% of hosts are superhosts

# %%
superhost = df_listings[df_listings['Superhost?'] == 1]  # Subset df to only those with HigherEd of 1
notsuperhost = df_listings[df_listings['Superhost?'] == 0]  # Subset df to only those with HigherEd of 0


print(superhost['Superhost?'][:5]) #Assure it looks like what you would expect
print(notsuperhost['Superhost?'][:5]) #Assure it looks like what you would expect
# Out:
# 1     1
# 6     1
# 7     1
# 9     1
# 10    1
# Name: Superhost?, dtype: int64
# 0    0
# 2    0
# 3    0
# 4    0
# 5    0
# Name: Superhost?, dtype: int64

# %%
# Check for instant booking, cancellation policy and room type 
instant_booking = df_listings['instant_bookable'].value_counts()
instant_booking
# Out:
# f    3227
# t     591
# Name: instant_bookable, dtype: int64

# %%
#Check your subset is correct - you should get a plot that was created using pandas styling
#which you can learn more about here: https://pandas.pydata.org/pandas-docs/stable/style.html

def test_values_for_superhost(field_to_test) :
    ed_1_perc = superhost[field_to_test].value_counts().reset_index()
    ed_1_perc.rename(columns={'index': field_to_test, field_to_test: 'count'}, inplace=True)
    ed_1_perc.set_index(field_to_test,inplace=True)
    ed_1_perc = ed_1_perc/ed_1_perc.sum()
    ed_1_perc

    ed_0_perc = notsuperhost[field_to_test].value_counts().reset_index()
    ed_0_perc.rename(columns={'index': field_to_test, field_to_test: 'count'}, inplace=True)
    ed_0_perc.set_index(field_to_test,inplace=True)
    ed_0_perc = ed_0_perc/ed_0_perc.sum()

    comp_df = pd.merge(ed_1_perc, ed_0_perc, left_index=True, right_index=True)
    comp_df.columns = [ 'superhost','nonsuperhost']

    comp_df['Diff_superHost_Vals'] = comp_df['superhost'] - comp_df['nonsuperhost']
    return comp_df

# %%
#Instant Bookable
comp_df = test_values_for_superhost('instant_bookable')
comp_df.style.bar(subset=['Diff_superHost_Vals'])
# Out:
#         <style  type="text/css" >
#
#
#             #T_67f27066_b65a_11e9_87fb_a0999b021721row0_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0%);
#
#             }
#
#             #T_67f27066_b65a_11e9_87fb_a0999b021721row1_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#         </style>
#
#         <table id="T_67f27066_b65a_11e9_87fb_a0999b021721" None>
#
#
#         <thead>
#
#             <tr>
#
#                 <th class="blank">
#
#                 <th class="col_heading level0 col0">superhost
#
#                 <th class="col_heading level0 col1">nonsuperhost
#
#                 <th class="col_heading level0 col2">Diff_superHost_Vals
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#                 <th id="T_67f27066_b65a_11e9_87fb_a0999b021721" class="row_heading level2 row0">
#
#                         f
#
#
#                 <td id="T_67f27066_b65a_11e9_87fb_a0999b021721row0_col0" class="data row0 col0">
#
#                         0.786632
#
#
#                 <td id="T_67f27066_b65a_11e9_87fb_a0999b021721row0_col1" class="data row0 col1">
#
#                         0.860197
#
#
#                 <td id="T_67f27066_b65a_11e9_87fb_a0999b021721row0_col2" class="data row0 col2">
#
#                         -0.073565
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_67f27066_b65a_11e9_87fb_a0999b021721" class="row_heading level2 row1">
#
#                         t
#
#
#                 <td id="T_67f27066_b65a_11e9_87fb_a0999b021721row1_col0" class="data row1 col0">
#
#                         0.213368
#
#
#                 <td id="T_67f27066_b65a_11e9_87fb_a0999b021721row1_col1" class="data row1 col1">
#
#                         0.139803
#
#
#                 <td id="T_67f27066_b65a_11e9_87fb_a0999b021721row1_col2" class="data row1 col2">
#
#                         0.073565
#
#
#             </tr>
#
#         </tbody>
#         </table>

# %%
#Room type 
comp_df = test_values_for_superhost('room_type')
comp_df.style.bar(subset=['Diff_superHost_Vals'])
# Out:
#         <style  type="text/css" >
#
#
#             #T_67f7d68c_b65a_11e9_887d_a0999b021721row0_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 57.4572860018%, transparent 0%);
#
#             }
#
#             #T_67f7d68c_b65a_11e9_887d_a0999b021721row1_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_67f7d68c_b65a_11e9_887d_a0999b021721row2_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0%);
#
#             }
#
#         </style>
#
#         <table id="T_67f7d68c_b65a_11e9_887d_a0999b021721" None>
#
#
#         <thead>
#
#             <tr>
#
#                 <th class="blank">
#
#                 <th class="col_heading level0 col0">superhost
#
#                 <th class="col_heading level0 col1">nonsuperhost
#
#                 <th class="col_heading level0 col2">Diff_superHost_Vals
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#                 <th id="T_67f7d68c_b65a_11e9_887d_a0999b021721" class="row_heading level2 row0">
#
#                         Entire home/apt
#
#
#                 <td id="T_67f7d68c_b65a_11e9_887d_a0999b021721row0_col0" class="data row0 col0">
#
#                         0.667095
#
#
#                 <td id="T_67f7d68c_b65a_11e9_887d_a0999b021721row0_col1" class="data row0 col1">
#
#                         0.665132
#
#
#                 <td id="T_67f7d68c_b65a_11e9_887d_a0999b021721row0_col2" class="data row0 col2">
#
#                         0.001964
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_67f7d68c_b65a_11e9_887d_a0999b021721" class="row_heading level2 row1">
#
#                         Private room
#
#
#                 <td id="T_67f7d68c_b65a_11e9_887d_a0999b021721row1_col0" class="data row1 col0">
#
#                         0.318766
#
#
#                 <td id="T_67f7d68c_b65a_11e9_887d_a0999b021721row1_col1" class="data row1 col1">
#
#                         0.3
#
#
#                 <td id="T_67f7d68c_b65a_11e9_887d_a0999b021721row1_col2" class="data row1 col2">
#
#                         0.018766
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_67f7d68c_b65a_11e9_887d_a0999b021721" class="row_heading level2 row2">
#
#                         Shared room
#
#
#                 <td id="T_67f7d68c_b65a_11e9_887d_a0999b021721row2_col0" class="data row2 col0">
#
#                         0.014139
#
#
#                 <td id="T_67f7d68c_b65a_11e9_887d_a0999b021721row2_col1" class="data row2 col1">
#
#                         0.034868
#
#
#                 <td id="T_67f7d68c_b65a_11e9_887d_a0999b021721row2_col2" class="data row2 col2">
#
#                         -0.02073
#
#
#             </tr>
#
#         </tbody>
#         </table>

# %%
#Cancellation policy
comp_df = test_values_for_superhost('cancellation_policy')
comp_df.style.bar(subset=['Diff_superHost_Vals'])
# Out:
#         <style  type="text/css" >
#
#
#             #T_67fe096b_b65a_11e9_9a72_a0999b021721row0_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_67fe096b_b65a_11e9_9a72_a0999b021721row1_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0%);
#
#             }
#
#             #T_67fe096b_b65a_11e9_9a72_a0999b021721row2_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 99.8745152585%, transparent 0%);
#
#             }
#
#         </style>
#
#         <table id="T_67fe096b_b65a_11e9_9a72_a0999b021721" None>
#
#
#         <thead>
#
#             <tr>
#
#                 <th class="blank">
#
#                 <th class="col_heading level0 col0">superhost
#
#                 <th class="col_heading level0 col1">nonsuperhost
#
#                 <th class="col_heading level0 col2">Diff_superHost_Vals
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#                 <th id="T_67fe096b_b65a_11e9_9a72_a0999b021721" class="row_heading level2 row0">
#
#                         strict
#
#
#                 <td id="T_67fe096b_b65a_11e9_9a72_a0999b021721row0_col0" class="data row0 col0">
#
#                         0.430591
#
#
#                 <td id="T_67fe096b_b65a_11e9_9a72_a0999b021721row0_col1" class="data row0 col1">
#
#                         0.355921
#
#
#                 <td id="T_67fe096b_b65a_11e9_9a72_a0999b021721row0_col2" class="data row0 col2">
#
#                         0.07467
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_67fe096b_b65a_11e9_9a72_a0999b021721" class="row_heading level2 row1">
#
#                         flexible
#
#
#                 <td id="T_67fe096b_b65a_11e9_9a72_a0999b021721row1_col0" class="data row1 col0">
#
#                         0.182519
#
#
#                 <td id="T_67fe096b_b65a_11e9_9a72_a0999b021721row1_col1" class="data row1 col1">
#
#                         0.331579
#
#
#                 <td id="T_67fe096b_b65a_11e9_9a72_a0999b021721row1_col2" class="data row1 col2">
#
#                         -0.14906
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_67fe096b_b65a_11e9_9a72_a0999b021721" class="row_heading level2 row2">
#
#                         moderate
#
#
#                 <td id="T_67fe096b_b65a_11e9_9a72_a0999b021721row2_col0" class="data row2 col0">
#
#                         0.386889
#
#
#                 <td id="T_67fe096b_b65a_11e9_9a72_a0999b021721row2_col1" class="data row2 col1">
#
#                         0.3125
#
#
#                 <td id="T_67fe096b_b65a_11e9_9a72_a0999b021721row2_col2" class="data row2 col2">
#
#                         0.074389
#
#
#             </tr>
#
#         </tbody>
#         </table>

# %%
#Response time
comp_df = test_values_for_superhost('host_response_time')
comp_df.style.bar(subset=['Diff_superHost_Vals'])
# Out:
#         <style  type="text/css" >
#
#
#             #T_68052511_b65a_11e9_bac9_a0999b021721row0_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_68052511_b65a_11e9_bac9_a0999b021721row1_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 30.9710119885%, transparent 0%);
#
#             }
#
#             #T_68052511_b65a_11e9_bac9_a0999b021721row2_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0%);
#
#             }
#
#             #T_68052511_b65a_11e9_bac9_a0999b021721row3_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 38.1682341422%, transparent 0%);
#
#             }
#
#         </style>
#
#         <table id="T_68052511_b65a_11e9_bac9_a0999b021721" None>
#
#
#         <thead>
#
#             <tr>
#
#                 <th class="blank">
#
#                 <th class="col_heading level0 col0">superhost
#
#                 <th class="col_heading level0 col1">nonsuperhost
#
#                 <th class="col_heading level0 col2">Diff_superHost_Vals
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#                 <th id="T_68052511_b65a_11e9_bac9_a0999b021721" class="row_heading level2 row0">
#
#                         within an hour
#
#
#                 <td id="T_68052511_b65a_11e9_bac9_a0999b021721row0_col0" class="data row0 col0">
#
#                         0.656376
#
#
#                 <td id="T_68052511_b65a_11e9_bac9_a0999b021721row0_col1" class="data row0 col1">
#
#                         0.471765
#
#
#                 <td id="T_68052511_b65a_11e9_bac9_a0999b021721row0_col2" class="data row0 col2">
#
#                         0.184611
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_68052511_b65a_11e9_bac9_a0999b021721" class="row_heading level2 row1">
#
#                         within a few hours
#
#
#                 <td id="T_68052511_b65a_11e9_bac9_a0999b021721row1_col0" class="data row1 col0">
#
#                         0.265772
#
#
#                 <td id="T_68052511_b65a_11e9_bac9_a0999b021721row1_col1" class="data row1 col1">
#
#                         0.301961
#
#
#                 <td id="T_68052511_b65a_11e9_bac9_a0999b021721row1_col2" class="data row1 col2">
#
#                         -0.036189
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_68052511_b65a_11e9_bac9_a0999b021721" class="row_heading level2 row2">
#
#                         within a day
#
#
#                 <td id="T_68052511_b65a_11e9_bac9_a0999b021721row2_col0" class="data row2 col0">
#
#                         0.07651
#
#
#                 <td id="T_68052511_b65a_11e9_bac9_a0999b021721row2_col1" class="data row2 col1">
#
#                         0.211765
#
#
#                 <td id="T_68052511_b65a_11e9_bac9_a0999b021721row2_col2" class="data row2 col2">
#
#                         -0.135255
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_68052511_b65a_11e9_bac9_a0999b021721" class="row_heading level2 row3">
#
#                         a few days or more
#
#
#                 <td id="T_68052511_b65a_11e9_bac9_a0999b021721row3_col0" class="data row3 col0">
#
#                         0.001342
#
#
#                 <td id="T_68052511_b65a_11e9_bac9_a0999b021721row3_col1" class="data row3 col1">
#
#                         0.01451
#
#
#                 <td id="T_68052511_b65a_11e9_bac9_a0999b021721row3_col2" class="data row3 col2">
#
#                         -0.013168
#
#
#             </tr>
#
#         </tbody>
#         </table>

# %%
#Count of listings
comp_df = test_values_for_superhost('host_total_listings_count')
comp_df.style.bar(subset=['Diff_superHost_Vals'])
# Out:
#         <style  type="text/css" >
#
#
#             #T_6811db2b_b65a_11e9_8608_a0999b021721row0_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0%);
#
#             }
#
#             #T_6811db2b_b65a_11e9_8608_a0999b021721row1_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_6811db2b_b65a_11e9_8608_a0999b021721row2_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 66.0473046014%, transparent 0%);
#
#             }
#
#             #T_6811db2b_b65a_11e9_8608_a0999b021721row3_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 70.0859241323%, transparent 0%);
#
#             }
#
#             #T_6811db2b_b65a_11e9_8608_a0999b021721row4_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 74.5711514822%, transparent 0%);
#
#             }
#
#             #T_6811db2b_b65a_11e9_8608_a0999b021721row5_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 52.4063081038%, transparent 0%);
#
#             }
#
#             #T_6811db2b_b65a_11e9_8608_a0999b021721row6_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 57.9101472014%, transparent 0%);
#
#             }
#
#             #T_6811db2b_b65a_11e9_8608_a0999b021721row7_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 62.4071111331%, transparent 0%);
#
#             }
#
#         </style>
#
#         <table id="T_6811db2b_b65a_11e9_8608_a0999b021721" None>
#
#
#         <thead>
#
#             <tr>
#
#                 <th class="blank">
#
#                 <th class="col_heading level0 col0">superhost
#
#                 <th class="col_heading level0 col1">nonsuperhost
#
#                 <th class="col_heading level0 col2">Diff_superHost_Vals
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#                 <th id="T_6811db2b_b65a_11e9_8608_a0999b021721" class="row_heading level2 row0">
#
#                         1.0
#
#
#                 <td id="T_6811db2b_b65a_11e9_8608_a0999b021721row0_col0" class="data row0 col0">
#
#                         0.508997
#
#
#                 <td id="T_6811db2b_b65a_11e9_8608_a0999b021721row0_col1" class="data row0 col1">
#
#                         0.586899
#
#
#                 <td id="T_6811db2b_b65a_11e9_8608_a0999b021721row0_col2" class="data row0 col2">
#
#                         -0.077902
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_6811db2b_b65a_11e9_8608_a0999b021721" class="row_heading level2 row1">
#
#                         2.0
#
#
#                 <td id="T_6811db2b_b65a_11e9_8608_a0999b021721row1_col0" class="data row1 col0">
#
#                         0.209512
#
#
#                 <td id="T_6811db2b_b65a_11e9_8608_a0999b021721row1_col1" class="data row1 col1">
#
#                         0.150428
#
#
#                 <td id="T_6811db2b_b65a_11e9_8608_a0999b021721row1_col2" class="data row1 col2">
#
#                         0.059084
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_6811db2b_b65a_11e9_8608_a0999b021721" class="row_heading level2 row2">
#
#                         3.0
#
#
#                 <td id="T_6811db2b_b65a_11e9_8608_a0999b021721row2_col0" class="data row2 col0">
#
#                         0.078406
#
#
#                 <td id="T_6811db2b_b65a_11e9_8608_a0999b021721row2_col1" class="data row2 col1">
#
#                         0.065833
#
#
#                 <td id="T_6811db2b_b65a_11e9_8608_a0999b021721row2_col2" class="data row2 col2">
#
#                         0.012573
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_6811db2b_b65a_11e9_8608_a0999b021721" class="row_heading level2 row3">
#
#                         4.0
#
#
#                 <td id="T_6811db2b_b65a_11e9_8608_a0999b021721row3_col0" class="data row3 col0">
#
#                         0.053985
#
#
#                 <td id="T_6811db2b_b65a_11e9_8608_a0999b021721row3_col1" class="data row3 col1">
#
#                         0.035879
#
#
#                 <td id="T_6811db2b_b65a_11e9_8608_a0999b021721row3_col2" class="data row3 col2">
#
#                         0.018106
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_6811db2b_b65a_11e9_8608_a0999b021721" class="row_heading level2 row4">
#
#                         5.0
#
#
#                 <td id="T_6811db2b_b65a_11e9_8608_a0999b021721row4_col0" class="data row4 col0">
#
#                         0.044987
#
#
#                 <td id="T_6811db2b_b65a_11e9_8608_a0999b021721row4_col1" class="data row4 col1">
#
#                         0.020737
#
#
#                 <td id="T_6811db2b_b65a_11e9_8608_a0999b021721row4_col2" class="data row4 col2">
#
#                         0.02425
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_6811db2b_b65a_11e9_8608_a0999b021721" class="row_heading level2 row5">
#
#                         6.0
#
#
#                 <td id="T_6811db2b_b65a_11e9_8608_a0999b021721row5_col0" class="data row5 col0">
#
#                         0.007712
#
#
#                 <td id="T_6811db2b_b65a_11e9_8608_a0999b021721row5_col1" class="data row5 col1">
#
#                         0.013825
#
#
#                 <td id="T_6811db2b_b65a_11e9_8608_a0999b021721row5_col2" class="data row5 col2">
#
#                         -0.006113
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_6811db2b_b65a_11e9_8608_a0999b021721" class="row_heading level2 row6">
#
#                         7.0

# %%
#Review scores rating
comp_df = test_values_for_superhost('review_scores_rating')
comp_df = comp_df.sort_values(by="superhost", ascending=False)
comp_df.style.bar(subset=['Diff_superHost_Vals'])
# Out:
#         <style  type="text/css" >
#
#
#             #T_681f4d5c_b65a_11e9_8984_a0999b021721row0_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_681f4d5c_b65a_11e9_8984_a0999b021721row1_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0%);
#
#             }
#
#             #T_681f4d5c_b65a_11e9_8984_a0999b021721row2_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 73.1920049412%, transparent 0%);
#
#             }
#
#             #T_681f4d5c_b65a_11e9_8984_a0999b021721row3_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 75.9577948666%, transparent 0%);
#
#             }
#
#             #T_681f4d5c_b65a_11e9_8984_a0999b021721row4_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 49.5128886679%, transparent 0%);
#
#             }
#
#             #T_681f4d5c_b65a_11e9_8984_a0999b021721row5_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 22.7708021304%, transparent 0%);
#
#             }
#
#             #T_681f4d5c_b65a_11e9_8984_a0999b021721row6_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 20.0699340717%, transparent 0%);
#
#             }
#
#             #T_681f4d5c_b65a_11e9_8984_a0999b021721row7_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 9.62994535907%, transparent 0%);
#
#             }
#
#             #T_681f4d5c_b65a_11e9_8984_a0999b021721row8_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 15.1954661252%, transparent 0%);
#
#             }
#
#             #T_681f4d5c_b65a_11e9_8984_a0999b021721row9_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 18.834445293%, transparent 0%);
#
#             }
#
#             #T_681f4d5c_b65a_11e9_8984_a0999b021721row10_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 18.7685367716%, transparent 0%);
#
#             }
#
#             #T_681f4d5c_b65a_11e9_8984_a0999b021721row11_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 16.0680633748%, transparent 0%);
#
#             }
#
#             #T_681f4d5c_b65a_11e9_8984_a0999b021721row12_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 24.926839568%, transparent 0%);
#
#             }
#
#             #T_681f4d5c_b65a_11e9_8984_a0999b021721row13_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 28.4835317496%, transparent 0%);
#
#             }
#
#             #T_681f4d5c_b65a_11e9_8984_a0999b021721row14_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 30.1136823328%, transparent 0%);
#
#             }
#
#         </style>
#
#         <table id="T_681f4d5c_b65a_11e9_8984_a0999b021721" None>
#
#
#         <thead>
#
#             <tr>
#
#                 <th class="blank">
#
#                 <th class="col_heading level0 col0">superhost
#
#                 <th class="col_heading level0 col1">nonsuperhost
#
#                 <th class="col_heading level0 col2">Diff_superHost_Vals
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#                 <th id="T_681f4d5c_b65a_11e9_8984_a0999b021721" class="row_heading level2 row0">
#
#                         98.0
#
#
#                 <td id="T_681f4d5c_b65a_11e9_8984_a0999b021721row0_col0" class="data row0 col0">
#
#                         0.238349
#
#
#                 <td id="T_681f4d5c_b65a_11e9_8984_a0999b021721row0_col1" class="data row0 col1">
#
#                         0.046694
#
#
#                 <td id="T_681f4d5c_b65a_11e9_8984_a0999b021721row0_col2" class="data row0 col2">
#
#                         0.191655
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_681f4d5c_b65a_11e9_8984_a0999b021721" class="row_heading level2 row1">
#
#                         100.0
#
#
#                 <td id="T_681f4d5c_b65a_11e9_8984_a0999b021721row1_col0" class="data row1 col0">
#
#                         0.17976
#
#
#                 <td id="T_681f4d5c_b65a_11e9_8984_a0999b021721row1_col1" class="data row1 col1">
#
#                         0.266942
#
#
#                 <td id="T_681f4d5c_b65a_11e9_8984_a0999b021721row1_col2" class="data row1 col2">
#
#                         -0.087182
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_681f4d5c_b65a_11e9_8984_a0999b021721" class="row_heading level2 row2">
#
#                         97.0
#
#
#                 <td id="T_681f4d5c_b65a_11e9_8984_a0999b021721row2_col0" class="data row2 col0">
#
#                         0.173103
#
#
#                 <td id="T_681f4d5c_b65a_11e9_8984_a0999b021721row2_col1" class="data row2 col1">
#
#                         0.056198
#
#
#                 <td id="T_681f4d5c_b65a_11e9_8984_a0999b021721row2_col2" class="data row2 col2">
#
#                         0.116904
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_681f4d5c_b65a_11e9_8984_a0999b021721" class="row_heading level2 row3">
#
#                         99.0
#
#
#                 <td id="T_681f4d5c_b65a_11e9_8984_a0999b021721row3_col0" class="data row3 col0">
#
#                         0.141145
#
#
#                 <td id="T_681f4d5c_b65a_11e9_8984_a0999b021721row3_col1" class="data row3 col1">
#
#                         0.016529

# %%
#Number of reviews
comp_df = test_values_for_superhost('number_of_reviews')
# comp_df = comp_df.sort_values(by="superhost", ascending=False)
comp_df.style.bar(subset=['Diff_superHost_Vals'])
# Out:
#         <style  type="text/css" >
#
#
#             #T_682bad7d_b65a_11e9_8815_a0999b021721row0_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0%);
#
#             }
#
#             #T_682bad7d_b65a_11e9_8815_a0999b021721row1_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 51.6706612153%, transparent 0%);
#
#             }
#
#             #T_682bad7d_b65a_11e9_8815_a0999b021721row2_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 65.5980074252%, transparent 0%);
#
#             }
#
#             #T_682bad7d_b65a_11e9_8815_a0999b021721row3_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 68.874947131%, transparent 0%);
#
#             }
#
#             #T_682bad7d_b65a_11e9_8815_a0999b021721row4_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 71.9150336012%, transparent 0%);
#
#             }
#
#             #T_682bad7d_b65a_11e9_8815_a0999b021721row5_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 77.2503407115%, transparent 0%);
#
#             }
#
#             #T_682bad7d_b65a_11e9_8815_a0999b021721row6_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 78.8956247944%, transparent 0%);
#
#             }
#
#             #T_682bad7d_b65a_11e9_8815_a0999b021721row7_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 79.2781615677%, transparent 0%);
#
#             }
#
#             #T_682bad7d_b65a_11e9_8815_a0999b021721row8_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 89.3970581324%, transparent 0%);
#
#             }
#
#             #T_682bad7d_b65a_11e9_8815_a0999b021721row9_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 85.2939517834%, transparent 0%);
#
#             }
#
#             #T_682bad7d_b65a_11e9_8815_a0999b021721row10_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 85.3108698717%, transparent 0%);
#
#             }
#
#             #T_682bad7d_b65a_11e9_8815_a0999b021721row11_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 91.739743409%, transparent 0%);
#
#             }
#
#             #T_682bad7d_b65a_11e9_8815_a0999b021721row12_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 88.1681469994%, transparent 0%);
#
#             }
#
#             #T_682bad7d_b65a_11e9_8815_a0999b021721row13_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 90.3280229334%, transparent 0%);
#
#             }
#
#             #T_682bad7d_b65a_11e9_8815_a0999b021721row14_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 89.8303491705%, transparent 0%);
#
#             }
#
#             #T_682bad7d_b65a_11e9_8815_a0999b021721row15_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 95.5618215142%, transparent 0%);
#
#             }
#
#             #T_682bad7d_b65a_11e9_8815_a0999b021721row16_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 92.1730344471%, transparent 0%);
#
#             }
#
#             #T_682bad7d_b65a_11e9_8815_a0999b021721row17_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 96.841486912%, transparent 0%);
#
#             }
#
#             #T_682bad7d_b65a_11e9_8815_a0999b021721row18_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 90.5954227172%, transparent 0%);
#
#             }
#
#             #T_682bad7d_b65a_11e9_8815_a0999b021721row19_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 90.6123408055%, transparent 0%);
#
#             }
#
#             #T_682bad7d_b65a_11e9_8815_a0999b021721row20_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 93.8352366183%, transparent 0%);
#
#             }
#
#             #T_682bad7d_b65a_11e9_8815_a0999b021721row21_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 92.9550260821%, transparent 0%);
#
#             }
#
#             #T_682bad7d_b65a_11e9_8815_a0999b021721row22_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 94.9320926735%, transparent 0%);
#
#             }
#
#             #T_682bad7d_b65a_11e9_8815_a0999b021721row23_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 95.2977113586%, transparent 0%);
#
#             }
#
#             #T_682bad7d_b65a_11e9_8815_a0999b021721row24_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 95.6633300437%, transparent 0%);
#
#             }
#
#             #T_682bad7d_b65a_11e9_8815_a0999b021721row25_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 97.4575872926%, transparent 0%);
#
#             }
#
#             #T_682bad7d_b65a_11e9_8815_a0999b021721row26_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 97.6403966352%, transparent 0%);
#
#             }
#
#             #T_682bad7d_b65a_11e9_8815_a0999b021721row27_col2 {

# %% [markdown]
# ### CONCLUSION: There are many factors that make an airbnb host a superhost. From our analysis, we can conclude that airbnbs with superhosts are generally entire home/ apt, are more instant bookable,  and have higher review rating and number of reviews. Also, superhosts have higher response time and have more no. of listings as compared to hosts that are not superhosts. One suprising thing we discovered was that the cancellation policy for more superhosts were morderate and strict as compared to non superhosts.
