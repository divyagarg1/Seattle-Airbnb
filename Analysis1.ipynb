# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df_listings = pd.read_csv('./listings.csv')
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0   241032   https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1   953595   https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
# 2  3308979  https://www.airbnb.com/rooms/3308979  20160104002432   2016-01-04
# 3  7421966  https://www.airbnb.com/rooms/7421966  20160104002432   2016-01-04
# 4   278830   https://www.airbnb.com/rooms/278830  20160104002432   2016-01-04
#
#                                   name  \
# 0         Stylish Queen Anne Apartment
# 1   Bright & Airy Queen Anne Apartment
# 2  New Modern House-Amazing water view
# 3                   Queen Anne Chateau
# 4       Charming craftsman 3 bdm house
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# ...

# %%
df_listings.head()
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0   241032   https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1   953595   https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
# 2  3308979  https://www.airbnb.com/rooms/3308979  20160104002432   2016-01-04
# 3  7421966  https://www.airbnb.com/rooms/7421966  20160104002432   2016-01-04
# 4   278830   https://www.airbnb.com/rooms/278830  20160104002432   2016-01-04
#
#                                   name  \
# 0         Stylish Queen Anne Apartment
# 1   Bright & Airy Queen Anne Apartment
# 2  New Modern House-Amazing water view
# 3                   Queen Anne Chateau
# 4       Charming craftsman 3 bdm house
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# ...

# %%
no_nulls = set(df_listings.columns[df_listings.isnull().mean()==0])

# %%
no_nulls
# Out:
# {'accommodates',
#  'amenities',
#  'availability_30',
#  'availability_365',
#  'availability_60',
#  'availability_90',
#  'bed_type',
#  'calculated_host_listings_count',
#  'calendar_last_scraped',
#  'calendar_updated',
#  'cancellation_policy',
#  'city',
#  'country',
#  'country_code',
#  'description',
#  'experiences_offered',
#  'extra_people',
#  'guests_included',
#  'has_availability',
#  'host_id',
#  'host_url',
#  'host_verifications',
#  'id',
#  'instant_bookable',
#  'is_location_exact',
#  'jurisdiction_names',
#  'last_scraped',
#  'latitude',
#  'listing_url',
#  'longitude',
#  'market',
#  'maximum_nights',
#  'minimum_nights',
#  'name',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'number_of_reviews',
#  'picture_url',
#  'price',
#  'require_guest_phone_verification',
#  'require_guest_profile_picture',
#  'requires_license',
#  'room_type',
#  'scrape_id',
#  'smart_location',
#  'state',
#  'street'}

# %%
most_missing_cols = set(df_listings.columns[df_listings.isnull().mean()>.75]) #Provide a set of columns with more than 75% of the values missing

most_missing_cols
# Out:
# {'license', 'square_feet'}

# %%
status_vals = df_listings['accommodates'].value_counts() #Provide a pandas series of the counts for each Professional status

# The below should be a bar chart of the proportion of individuals in each professional category if your status_vals
# is set up correctly.

(status_vals/df_listings.shape[0]).plot(kind="bar");
plt.title("Airbnb accomodates?");

# %%
ed_vals = df_listings['room_type'].value_counts()#Provide a pandas series of the counts for each FormalEducation status

# The below should be a bar chart of the proportion of individuals in your ed_vals
# if it is set up correctly.

(ed_vals/df_listings.shape[0]).plot(kind="bar");
plt.title("Room Type");

# %%
ed_vals = df_listings['price'].value_counts()#Provide a pandas series of the counts for each FormalEducation status

# The below should be a bar chart of the proportion of individuals in your ed_vals
# if it is set up correctly.

(ed_vals/df_listings.shape[0]).plot(kind="bar");
plt.title("Price");
